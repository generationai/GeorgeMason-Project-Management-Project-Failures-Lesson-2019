# %% [markdown]
# # Learning how to understand a project management dataset and build models in Python for further analysis
# Today we will be exploring a synthetically generated dataset based on the PERIL database. Learn more about the PERIL dataset and it's creator Tom Kendrick [here](http://www.failureproofprojects.com/peril.php).

# %% [markdown]
# To accomplish our task of understanding the data, we will need to use some Python libraries. Python libraries can be summarized as code other people have written and shared that we can use to save us time. We can import and use that code with a small import statement. Some of the packages we will use today include [Pandas](https://towardsdatascience.com/a-quick-introduction-to-the-pandas-python-library-f1b678f34673), [Scipy](https://www.scipy.org/getting-started.html), [Numpy](https://docs.scipy.org/doc/numpy-1.15.0/user/whatisnumpy.html), and [MatPlotLib](https://matplotlib.org/). If you want to learn more about how these different packages work with examples, click [here](http://cs231n.github.io/python-numpy-tutorial/).

# %%
#Importing python libraries which help us speed our coding up.
#The packages we're importing are below.
import pandas as pd
import random
from pandas.plotting import scatter_matrix
import scipy as sc
import numpy as np
import matplotlib
import matplotlib.pyplot as plt #Can abbreviate specific parts of the packages so it's easier to type
import sklearn as sk
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model

# %%
#We will now read the data in and store it in a variable called dataset
dataset = pd.read_excel('../git_data/Peril_Project_Management_Data.xlsx', header = 0, index = False)
dataset.insert(loc = 0, column = 'Project Number', value = np.arange(len(dataset)))

# %% [markdown]
# #### Understanding our data
# Let's run some code and see how many rows and columns we have. Below - you will see the result as (Number of Rows, Number of Columns)

# %%
dataset.shape
# Out:
# (5000, 14)

# %% [markdown]
# #### What do the first 10 rows of our data look like?

# %%
dataset.head(10)
# Out:
#    Project Number  Unnamed: 0 Parameter     Category              Sub cat  \
# 0               0           0  Resource        Money           Limitation
# 1               1           1  Resource  Outsourcing        Delayed start
# 2               2           2  Resource  Outsourcing  Late or poor output
# 3               3           3  Resource  Outsourcing  Late or poor output
# 4               4           4  Resource  Outsourcing  Late or poor output
# 5               5           5  Resource  Outsourcing  Late or poor output
# 6               6           6  Resource       People           Late start
# 7               7           7  Resource       People                 Loss
# 8               8           8  Resource       People           Motivation
# 9               9           9  Resource       People              Queuing
#
#    Impact  TRL                                        Description  \
# 0      18    5  Did not have sufficient resources and the cont...
# 1      17    4                 Contractor setup delayed by a week
# 2      13    5  Contractor did not spend time on the project b...
# 3      13    7         Contractors failed to show up as committed
# 4      13    3  Third-party vendor inadvertently introduced a ...
# 5      16    7      Outsouced staff lacked the necessary skillset
# 6      15    5  Planning delayed due to staff being still tied...
# 7      16    4  Chef quit two days before the café was schedul...
# 8      11    5  Work at customer site had to be done by union ...
# 9      16    6  Critical task assigned to a heavily booked expert
#
#    Region Numeric    Region      Project  Year     Month     Cost
# 0               0  Americas  IT/Solution  2010   October   700560
# 1               0  Americas   Prod. Dev.  2002       May   347922
# 2               0  Americas  IT/Solution  2002    August   919828
# 3               1      Asia  IT/Solution  2014      July   521495
# 4               0  Americas  IT/Solution  2010  November   322010
# 5               3    Africa  IT/Solution  2014      June   498896
# 6               0  Americas   Prod. Dev.  2015     April   592785
# 7               3    Africa  IT/Solution  2017   October   578928
# 8               3    Africa  IT/Solution  2003      July   318846
# 9               0  Americas  IT/Solution  2010      June  1109120

# %% [markdown]
# #### What are our column names?
# ##### As you can see above - we have 12 columns with different values
# Project Number: A unique number to identify each project.
# Parameter: The parameter of the project that was impacted. This dataset categorizes the risk in these three main groups of Scope, Resource, and Schedule.
# Category: The category of the risk. We have the following categories in the main parameters - Change(Scope), Defect(Scope), People(Resource), Money(Resource), Outsourcing(Resource), Delay(Schedule), Dependency(Schedule), Estimates(Schedule)
# Sub cat: The sub-category of the risk are the following - Creep, Dependency, Gap, Hardware, Software, Integration, Limitation, Late Start, Loss, Motivation, Queuing, Temp Loss, Decision, Information, Parts, Infrastructure, Legal, Project, Deadline, Judgement, and Learning
#
# <br>
# Below is the mapping for the Parameter -> Category -> Sub category:
# <br>
#
# *  Scope -> Change -> Creep
# *  Scope -> Change -> Dependency
# *  Scope -> Change -> Gap
# <br>
#
# *  Scope -> Defect -> Hardware
# *  Scope -> Defect -> Software
# *  Scope -> Defect -> Integration
# <br>
#
# *  Resource -> Money -> Limitation
# <br>
# *  Resource -> People -> Late Start
# *  Resource -> People -> Loss
# *  Resource -> People -> Motivation
# *  Resource -> People -> Queuing
# *  Resource -> People -> Temp Loss
# <br>
# *  Schedule -> Delay -> Decision
# *  Schedule -> Delay -> Hardware
# *  Schedule -> Delay -> Information
# *  Schedule -> Delay -> Parts
# <br>
# *  Schedule -> Dependency -> Infrastructure
# *  Schedule -> Dependency -> Legal
# *  Schedule -> Dependency -> Project
# <br>
# *  Schedule -> Estimates -> Deadline
# *  Schedule -> Estimates -> Judgement
# *  Schedule -> Estimates -> Learning
# <br>
#
# Impact: The impact to the project by number of weeks.
# TRL: The technology readiness level of the project. You can find more information [here](http://acqnotes.com/acqnote/tasks/technology-readiness-level).
# Description: The description of the issue.
# Region Numeric: A numeric value representing the region (0 = Americas, 1 = Asia, 2 = Eur/ME, 3 = Africa).
# Region: What region of the world did the issue occur in.
# Project: What type of project did the issue occur in. (Prod. Dev., or IT/Solution)
# Year: The year the issue occurred in.
# Cost: The cost, in USD, of the impact on the project.
# Month: The month the project failure occurred in.

# %% [markdown]
# #### Now let's get a breakdown of what are the counts of the values in each column
# Here we can see that there are three different types of parameters that each project is grouped into that we have: Scope, Resource, and Schedule. Below the chart are the raw counts of the projects in those parameter groups.

# %%
plt.figure(figsize = (3,10))
plot_parameter = dataset['Parameter'].value_counts().plot(kind='bar')
plot_parameter.set_xlabel("Parameter")
plot_parameter.set_ylabel("Count (Number of Projects)")
plt.title('The Count of Projects by the Parameter Type')
plot_parameter

# %%
dataset["Parameter"].value_counts()
# Out:
# Scope       1991
# Resource    1579
# Schedule    1430
# Name: Parameter, dtype: int64

# %% [markdown]
# What is the breakdown of the different Categories that we have? We find the following categories: Change, People, Delay, Defect, Outsourcing, Estimates, Dependency, and Money. Below the chart are the raw counts of the projects in those categories.

# %%
plot_category = dataset['Category'].value_counts().plot(kind='bar')
plot_category.set_xlabel("Category")
plot_category.set_ylabel("Count (Number of Projects)")
plt.title('The Count of Projects by Category')
plot_category

# %%
dataset["Category"].value_counts()
# Out:
# Change         1459
# People          943
# Delay           763
# Defect          532
# Outsourcing     465
# Estimates       369
# Dependency      298
# Money           171
# Name: Category, dtype: int64

# %% [markdown]
# What is the breakdown of the sub-categories? Here we find the following: Gap, Creep, Late or poor output, Hardware, Parts, Loss, Temp loss, Queueing, Software, Learning, Limitation, Information, Judgement, Decision, Dependency, Infrastructure, Project, Late start, Delayed start, Integration, Deadline, Motivation, Legal, Project, Infrastructure, and Late or poor output. Below the chart are the raw counts of the projects in those sub-categories.

# %%
plot_subcat = dataset['Sub cat'].value_counts().plot(kind='bar')
plot_subcat.set_xlabel("Sub-Category")
plot_subcat.set_ylabel("Count (Number of Projects)")
plt.title('The Count of Projects by the Sub-Category')
plot_subcat

# %%
dataset["Sub cat"].value_counts()
# Out:
# Gap                     768
# Creep                   576
# Late or poor output     380
# Hardware                373
# Parts                   315
# Loss                    298
# Temp loss               256
# Queuing                 250
# Software                249
# Learning                173
# Limitation              171
# Information             161
# Judgment                138
# Decision                134
# Dependency              115
# Infrastructure          113
# Project                  95
# Late start               93
# Delayed start            76
# Integration              63
# Deadline                 58
# Motivation               51
# Legal                    46
# Project                  37
# Infrastructure            7
# Late or poor output       4
# Name: Sub cat, dtype: int64

# %% [markdown]
# Here you can see that the Region column has four separate regions and the count of values in those regions is provided below in the table.

# %%
dataset["Region"].value_counts()
# Out:
# Americas    2872
# Eur/ME       945
# Africa       636
# Asia         547
# Name: Region, dtype: int64

# %% [markdown]
# What years do we have in our dataset? 2001-2019

# %%
dataset["Year"].value_counts()
# Out:
# 2010    578
# 2007    435
# 2019    364
# 2015    341
# 2002    267
# 2013    235
# 2003    233
# 2005    226
# 2012    225
# 2006    223
# 2004    223
# 2018    221
# 2001    219
# 2016    212
# 2011    205
# 2009    199
# 2008    199
# 2017    198
# 2014    197
# Name: Year, dtype: int64

# %% [markdown]
# What is the distribution of the Impact levels in our data?

# %%
plot_impact = dataset['Impact'].value_counts().plot(kind='bar')
plot_impact.set_xlabel("Impact Level")
plot_impact.set_ylabel("Count (Number of Projects)")
plt.title('The Count of Projects by the Impact Level')
plot_impact

# %% [markdown]
# ## Analysis
# #### Below we'll start looking at analyzing projects from different perspectives to understand which parameters, categories, sub-categories, TRL levels, regions, project types, and dates produced the highest costs and impacts.
#
# The Column Names and Values that can be inputted below:
#
# ##### The Project Number
# * A number between 0-4999.
#
# ##### Parameter
# * Scope
# * Resource
# * Schedule
#
# ##### Category
# * Change
# * Defect
# * Delay
# * Dependency
# * Estimates
# * Money
# * Outsourcing
# * People
#
# ##### Sub cat
# * Creep
# * Dependency
# * Gap
# * Hardware
# * Software
# * Integration
# * Limitation
# * Late Start
# * Loss
# * Motivation
# * Queuing
# * Temp Loss
# * Decision
# * Information
# * Parts
# * Infrastructure
# * Legal
# * Project
# * Deadline
# * Judgement
# * Learning
#
# ##### Impact
# * Numbers between 1-26 in weeks
#
# ##### TRL
# * Numbers between 1-9
#
# ##### Description
#
# ##### Region Numeric
# * 0: Americas
# * 1: Asia
# * 2: Eur/ME
# * 3: Africa
#
# ##### Region
# * Americas
# * Asia
# * Eur/ME
# * Africa
#
# ##### Project
# * IT/Solution
# * Prod. Dev.
#
# ##### Year
# * Years from 2001-2019
#
# ##### Cost
# * Number between 10787 and 2543242
#
# ##### Month
# * Any month in the calendar year (January - December)

# %% [markdown]
# __What is the cost distribution in our data? We find that we have a median between "500,000"  and  "1,000,000" and the cost values are skewed to the left.__

# %%
boxplot = dataset.boxplot(column=['Cost'], vert = False)
boxplot.set_xlabel("Cost (in USD)")
plt.title('Distribution of Cost of All Project Failures')
boxplot

# %% [markdown]
# __If we want to understand which projects contribute to the outliers, let's filter the data to projects where the cost of the failure was greater than 2,000,000 dollars. Let's also sort the data so we can see the projects with the highest cost failures first. If you want to see the data for a different range of costs, then change the number value after "['Cost'] >" to something else.__
#
# For example you can copy and paste the lines below to see the data for projects with a cost of failure less than 500,000 dollars: <br>
# dataset_high_cost = dataset[dataset['Cost'] < 500000] <br>
# dataset_high_cost = dataset_high_cost.sort_values(['Cost'], ascending = False) <br>
# dataset_high_cost = dataset_high_cost.reset_index(drop = True) <br>
# dataset_high_cost

# %%
dataset_high_cost = dataset[dataset['Cost']>2000000]
dataset_high_cost = dataset_high_cost.sort_values(['Cost'], ascending = False)
dataset_high_cost = dataset_high_cost.reset_index(drop = True) 
dataset_high_cost
# Out:
#     Project Number Parameter     Category              Sub cat  Impact  TRL  \
# 0             3842  Resource       People           Late start      26    3
# 1             4940     Scope       Change                  Gap      26    8
# 2             3705  Resource  Outsourcing        Delayed start      26    2
# 3             4956     Scope       Change                  Gap      26    6
# 4             4938     Scope       Change                  Gap      26    3
# 5             4077  Schedule   Dependency              Project      26    5
# 6             4991  Resource       People                 Loss      26    2
# 7             4788  Resource       People                 Loss      25    2
# 8             4549  Resource        Money           Limitation      26    4
# 9             4552  Resource        Money           Limitation      26    7
# 10            4133  Resource        Money           Limitation      24    6
# 11            4116     Scope       Change                  Gap      25    6
# 12            3580  Schedule        Delay                Parts      24    2
# 13            4925     Scope       Change                Creep      25    2
# 14            3394  Schedule   Dependency       Infrastructure      26    6
# 15            4251  Resource  Outsourcing  Late or poor output      26    2
# 16            4843  Resource  Outsourcing           Late start      25    4
# 17            3730  Resource       People              Queuing      24    6
# 18            4598  Resource  Outsourcing  Late or poor output      25    6
# 19            4797     Scope       Change                Creep      24    7
# 20            3523     Scope       Change                  Gap      24    8
# 21            4933     Scope       Change                  Gap      25    1
# 22            3740  Resource       People            Temp loss      23    5
# 23            4641  Resource       People            Temp loss      24    5
# 24            4753     Scope       Change                  Gap      25    3
# 25            4393  Resource       People                 Loss      25    3
# 26            4545     Scope       Change                  Gap      23    1
# 27            4595  Resource  Outsourcing        Delayed start      25    5
# 28            4725     Scope       Change                Creep      23    9
# 29            4875  Schedule        Delay             Hardware      25    9
# ..             ...       ...          ...                  ...     ...  ...
# 42            4905  Schedule    Estimates             Judgment      25    6
# 43            4864  Resource       People              Queuing      23    1
# 44            4083  Schedule    Estimates             Learning      22    5
# 45            4599  Resource  Outsourcing  Late or poor output      25    1
# 46            4747     Scope       Change                  Gap      26    3
# 47            4883  Schedule        Delay                Parts      24    4
# 48            4160  Schedule        Delay                Parts      24    7
# 49            4000  Resource       People                 Loss      26    9
# 50            4779     Scope       Defect             Software      23    3
# 51            3518  Schedule        Delay             Decision      24    2
# 52            4437  Resource        Money           Limitation      26    5
# 53            4316     Scope       Change                  Gap      23    9
# 54            3726  Resource       People                 Loss      24    9
# 55            4947     Scope       Change                  Gap      23    4
# 56            4986     Scope       Defect             Software      25    6
# 57            3831  Schedule        Delay             Hardware      22    4
# 58            4835  Resource  Outsourcing  Late or poor output      24    7
# 59            4682  Schedule        Delay                Parts      26    3
# 60            4183     Scope       Change                  Gap      25    9
# 61            3345  Resource       People            Temp loss      24    8
# 62            4318  Resource       People            Temp loss      22    2
# 63            3557  Resource       People              Queuing      24    3
# 64            3857  Resource       People                 Loss      25    7
# 65            3556  Resource       People              Queuing      25    1
# 66            3898  Resource  Outsourcing  Late or poor output      21    5
# 67            3878  Resource  Outsourcing  Late or poor output      22    8
# 68            3235     Scope       Defect             Hardware      21    9
# 69            3577  Schedule        Delay          Information      22    3
# 70            4453     Scope       Change                Creep      24    4
# 71            3329  Resource       People           Motivation      24    8
#
#                                           Description  Region Numeric  \
# 0   Change Management Lead took unexpected medical...               1
# 1   Chip failed and had to be refabricated with ch...               2
# 2   Project had to wait until all data collection ...               2
# 3         The scope of the project was poorly defined               0
# 4   Ship sinks with critical part; forced to repla...               0
# 5   Client's insisted on the use of "the latest te...               0
# 6   To expand business, unrealistic commitments we...               3
# 7   Contract lab failed to inform us that they had...               3
# 8   "Minor" changes added  and accepted late in pr...               0
# 9   Server technology chage was necessitated to su...               2
# 10         Shipping documents not filled in correctly               0
# 11          Key contributor out ill at critical time.               0
# 12  Team leader reassigned to another project and ...               0
# 13  Outsourcing partner in Switzerland did unneede...               0
# 14       Need to upgrade detected only at project end               2
# 15  Late in project, the budget and staff are cut ...               0
# 16  Internal supplier problem; needed components d...               3
# 17  Planning delayed due to staff being still tied...               0
# 18  Product owner having unique knowledge left the...               0
# 19               Late test results came back negative               3
# 20  Several employees had to take a leave of absen...               1
# 21  Negotiation and training on a new tool took mo...               0
# 22  Development plans failed to include all of the...               0
# 23  Delay in hiring more engineers due to cost cut...               3
# 24  Components do not work as documented.  Replace...               0
# 25  Software modules in system do not work togethe...               0
# 26                Escalated late changes from Sponsor               0
# 27  Market change due to Improvements in technolog...               0
# 28  User specifications not defined until late in ...               0
# 29                  Issues discovered late in testing               0
# ..                                                ...             ...
# 42  Lack of testing of older WWW browser versions ...               0
# 43  Lack of understanding by the manager of the sy...               2
# 44  Project delayed due to recent/last minute chan...               1
# 45  Poor communications resulted in never truly un...               0
# 46  Product developed for multiple platforms, but ...               0
# 47  Apartments were sold before construction begin...               2
# 48  Cable required had been left off the implement...               2
# 49  Client requested "15 minute" change accepted a...               1
# 50  Too few disc drives, and insufficient "owned" ...               0
# 51                              Poor Fit/Gap analysis               1
# 52  None of the developers had experience with the...               2
# 53                  Lack of spare parts and expertise               0
# 54  Project start delayed; staffing and buy-in lat...               1
# 55                                Inexperienced staff               0
# 56          Initial code release was a major failure                0
# 57  After more than 2/3 of the original budget had...               2
# 58  Parallel tasks require resources beyond what i...               2
# 59     Supplier was unable to make a sample correctly               2
# 60       Scope not defined well; huge software delays               0
# 61    Scope expanded during the course of the project               1
# 62  Move out of old location required, but new spa...               2
# 63  Inadequate procedures for acceptance, quality,...               1
# 64  Team was staffed by 3 successive new hires in ...               2
# 65  A pool of unqualified, poorly performing, marg...               1
# 66        Errors found  in data and critrical reports               1
# 67             Late stakeholders redefine requiremnts               2
# 68  Conversion from legacy system to SAP has multi...               2
# 69  Project team was not aware that the new releas...               2
# 70    Unexpectedly high demand requires outlisde help               0
# 71  Lack of head count from a 10% company-wide lay...               0
#
#       Region      Project  Year      Month     Cost
# 0       Asia  IT/Solution  2003   November  2562560
# 1     Eur/ME  IT/Solution  2018    January  2548442
# 2     Eur/ME   Prod. Dev.  2001    October  2543034
# 3   Americas  IT/Solution  2010  September  2535416
# 4   Americas   Prod. Dev.  2010   February  2533232
# 5   Americas  IT/Solution  2010        May  2526342
# 6     Africa   Prod. Dev.  2004        May  2504268
# 7     Africa   Prod. Dev.  2002   December  2469325
# 8   Americas  IT/Solution  2002    January  2437292
# 9     Eur/ME   Prod. Dev.  2015   December  2425748
# 10  Americas  IT/Solution  2006      March  2383512
# 11  Americas  IT/Solution  2019   December  2371375
# 12  Americas  IT/Solution  2014   November  2366784
# 13  Americas   Prod. Dev.  2010   November  2360300
# 14    Eur/ME   Prod. Dev.  2003      March  2357602
# 15  Americas   Prod. Dev.  2017      March  2350920
# 16    Africa   Prod. Dev.  2013       June  2326750
# 17  Americas   Prod. Dev.  2015     August  2324688
# 18  Americas  IT/Solution  2010   February  2316300
# 19    Africa  IT/Solution  2011    January  2309472
# 20      Asia   Prod. Dev.  2011     August  2301120
# 21  Americas   Prod. Dev.  2015  September  2292350
# 22  Americas  IT/Solution  2016    January  2286108
# 23    Africa  IT/Solution  2010       June  2286048
# 24  Americas  IT/Solution  2015  September  2285325
# 25  Americas   Prod. Dev.  2008      April  2276500
# 26  Americas  IT/Solution  2008    January  2276126
# 27  Americas  IT/Solution  2015        May  2265925
# 28  Americas  IT/Solution  2010       July  2259957
# 29  Americas   Prod. Dev.  2015        May  2257500
# ..       ...          ...   ...        ...      ...
# 42  Americas   Prod. Dev.  2015   November  2161575
# 43    Eur/ME   Prod. Dev.  2007      April  2157676
# 44      Asia   Prod. Dev.  2014      March  2150148
# 45  Americas  IT/Solution  2010      March  2149800
# 46  Americas   Prod. Dev.  2010       July  2127450
# 47    Eur/ME  IT/Solution  2007   December  2124000
# 48    Eur/ME  IT/Solution  2006      April  2106312
# 49      Asia   Prod. Dev.  2003   November  2098902
# 50  Americas   Prod. Dev.  2015     August  2095208
# 51      Asia   Prod. Dev.  2006   November  2094336
# 52    Eur/ME   Prod. Dev.  2009       July  2093078
# 53  Americas  IT/Solution  2011     August  2092333
# 54      Asia  IT/Solution  2011       June  2090328
# 55  Americas   Prod. Dev.  2015      April  2088676
# 56  Americas  IT/Solution  2010       July  2085275
# 57    Eur/ME   Prod. Dev.  2003      March  2085204
# 58    Eur/ME  IT/Solution  2001       July  2082432
# 59    Eur/ME  IT/Solution  2004    January  2081560
# 60  Americas  IT/Solution  2003       July  2075050
# 61      Asia  IT/Solution  2017   December  2055624
# 62    Eur/ME  IT/Solution  2017   November  2052248
# 63      Asia   Prod. Dev.  2015        May  2052144
# 64    Eur/ME  IT/Solution  2010      March  2050425
# 65      Asia   Prod. Dev.  2013  September  2041850
# 66      Asia  IT/Solution  2011      March  2040171
# 67    Eur/ME  IT/Solution  2017      April  2035968
# 68    Eur/ME  IT/Solution  2017      April  2033829
# 69    Eur/ME  IT/Solution  2016    January  2023054
# 70  Americas   Prod. Dev.  2010      April  2018520
# 71  Americas  IT/Solution  2003      March  2002488
#
# [72 rows x 13 columns]

# %% [markdown]
# We find 72 rows where the cost value is greater than $2,000,000. Let's plot the parameters, categories, and sub-categories off these project failures to get a better sense of what types of projects comprise these high cost failures. We'll start with the breakdown of these high cost failure projects by the parameter.

# %%
plot_high_cost = dataset_high_cost['Parameter'].value_counts().plot(kind='bar')
plt.xlabel('Parameter')
plt.ylabel('Count (of Project Failures)')
plt.title('The Count of High Cost Project Failures by Parameter')
# Out:
# Text(0.5,1,'The Count of High Cost Project Failures by Parameter')

# %% [markdown]
# Now let's look at the breakdown of these high cost failure projects by the Category.

# %%
plot_high_cost_by_category = dataset_high_cost['Category'].value_counts().plot(kind='bar')
plt.xlabel('Category')
plt.ylabel('Count (of Project Failures)')
plt.title('The Count of High Cost Project Failures by Category')
# Out:
# Text(0.5,1,'The Count of High Cost Project Failures by Category')

# %% [markdown]
# Now let's look at the breakdown of these high cost failure projects by the Sub-Category.

# %%
plot_high_cost_by_subcat = dataset_high_cost['Sub cat'].value_counts().plot(kind='bar')
plt.xlabel('Sub-Category')
plt.ylabel('Count (of Project Failures)')
plt.title('The Count of High Cost Project Failures by Sub-Category')
# Out:
# Text(0.5,1,'The Count of High Cost Project Failures by Sub-Category')

# %% [markdown]
# Let's plot these high cost project failures to see which region has the most.

# %%
plot_high_cost_by_region = dataset_high_cost['Region'].value_counts().plot(kind='bar')
plt.xlabel('Region')
plt.ylabel('Count (of Project Failures)')
plt.title('The Count of High Cost Project Failures by Region')
# Out:
# Text(0.5,1,'The Count of High Cost Project Failures by Region')

# %% [markdown]
# __Let's say we want to look at the data for the projects in the Americas region - we can run the following code. Let's also sort the data so we can see the projects with the highest cost failures first. If you want to see the data for a different region, then change 'Americas' to a different region (copy and paste the region name from above). For example you can copy and paste the line below to see the data for just the Europe/Middle East region:__

# %% [markdown]
# Copy and paste the code below: <br>
# region_filter = dataset.loc[dataset['Region'] == 'Eur/ME'] <br>
# region_filter = region_filter.sort_values(['Cost'], ascending = False) <br>
# region_filter = region_filter.reset_index(drop = True) <br>
# region_filter.head(50)

# %%
region_filter = dataset.loc[dataset['Region'] == 'Americas']
region_filter = region_filter.sort_values(['Cost'], ascending = False)
region_filter = region_filter.reset_index(drop = True) 
region_filter.head(50) #Let's look at the first 50 projects in the Americas
# Out:
#     Project Number Parameter     Category              Sub cat  Impact  TRL  \
# 0             4956     Scope       Change                  Gap      26    6
# 1             4938     Scope       Change                  Gap      26    3
# 2             4077  Schedule   Dependency              Project      26    5
# 3             4549  Resource        Money           Limitation      26    4
# 4             4133  Resource        Money           Limitation      24    6
# 5             4116     Scope       Change                  Gap      25    6
# 6             3580  Schedule        Delay                Parts      24    2
# 7             4925     Scope       Change                Creep      25    2
# 8             4251  Resource  Outsourcing  Late or poor output      26    2
# 9             3730  Resource       People              Queuing      24    6
# 10            4598  Resource  Outsourcing  Late or poor output      25    6
# 11            4933     Scope       Change                  Gap      25    1
# 12            3740  Resource       People            Temp loss      23    5
# 13            4753     Scope       Change                  Gap      25    3
# 14            4393  Resource       People                 Loss      25    3
# 15            4545     Scope       Change                  Gap      23    1
# 16            4595  Resource  Outsourcing        Delayed start      25    5
# 17            4725     Scope       Change                Creep      23    9
# 18            4875  Schedule        Delay             Hardware      25    9
# 19            3337  Resource       People              Queuing      25    6
# 20            4970     Scope       Change                  Gap      23    2
# 21            3469     Scope       Defect          Integration      26    3
# 22            3882  Schedule        Delay          Information      25    5
# 23            4423     Scope       Change                  Gap      22    7
# 24            4842  Resource  Outsourcing  Late or poor output      26    8
# 25            4905  Schedule    Estimates             Judgment      25    6
# 26            4599  Resource  Outsourcing  Late or poor output      25    1
# 27            4747     Scope       Change                  Gap      26    3
# 28            4779     Scope       Defect             Software      23    3
# 29            4316     Scope       Change                  Gap      23    9
# 30            4947     Scope       Change                  Gap      23    4
# 31            4986     Scope       Defect             Software      25    6
# 32            4183     Scope       Change                  Gap      25    9
# 33            4453     Scope       Change                Creep      24    4
# 34            3329  Resource       People           Motivation      24    8
# 35            4716  Schedule    Estimates             Judgment      21    4
# 36            4256  Resource  Outsourcing  Late or poor output      23    9
# 37            4035     Scope       Change                  Gap      22    6
# 38            4400  Schedule   Dependency             Project       24    2
# 39            3734  Resource       People            Temp loss      22    4
# 40            3615     Scope       Change                Creep      26    9
# 41            4660  Schedule        Delay             Decision      20    1
# 42            4505  Schedule        Delay                Parts      25    3
# 43            3838     Scope       Change                Creep      26    7
# 44            4650  Resource       People            Temp loss      21    9
# 45            4994  Schedule        Delay                Parts      24    7
# 46            4009  Resource  Outsourcing        Delayed start      25    1
# 47            3560  Resource       People              Queuing      26    2
# 48            4418     Scope       Change                  Gap      23    1
# 49            4500  Schedule        Delay             Hardware      25    6
#
#                                           Description  Region Numeric  \
# 0         The scope of the project was poorly defined               0
# 1   Ship sinks with critical part; forced to repla...               0
# 2   Client's insisted on the use of "the latest te...               0
# 3   "Minor" changes added  and accepted late in pr...               0
# 4          Shipping documents not filled in correctly               0
# 5           Key contributor out ill at critical time.               0
# 6   Team leader reassigned to another project and ...               0
# 7   Outsourcing partner in Switzerland did unneede...               0
# 8   Late in project, the budget and staff are cut ...               0
# 9   Planning delayed due to staff being still tied...               0
# 10  Product owner having unique knowledge left the...               0
# 11  Negotiation and training on a new tool took mo...               0
# 12  Development plans failed to include all of the...               0
# 13  Components do not work as documented.  Replace...               0
# 14  Software modules in system do not work togethe...               0
# 15                Escalated late changes from Sponsor               0
# 16  Market change due to Improvements in technolog...               0
# 17  User specifications not defined until late in ...               0
# 18                  Issues discovered late in testing               0
# 19  Building permit was issued late due to roof da...               0
# 20                 Defects discovered in late testing               0
# 21  Program Manager squeezes in additional functio...               0
# 22     Foundation was inadaquate and needed upgrading               0
# 23  Partner software is incompatible with current ...               0
# 24  The Project Lead did not hold the customer/bus...               0
# 25  Lack of testing of older WWW browser versions ...               0
# 26  Poor communications resulted in never truly un...               0
# 27  Product developed for multiple platforms, but ...               0
# 28  Too few disc drives, and insufficient "owned" ...               0
# 29                  Lack of spare parts and expertise               0
# 30                                Inexperienced staff               0
# 31          Initial code release was a major failure                0
# 32       Scope not defined well; huge software delays               0
# 33    Unexpectedly high demand requires outlisde help               0
# 34  Lack of head count from a 10% company-wide lay...               0
# 35  Changing product definition and poor estimatio...               0
# 36       Resources thin and tasks queued in backlogs.               0
# 37  The project team agreed to new requirements; u...               0
# 38         Controlled Document rejected  by Approvers               0
# 39  Programmers were volunteers, and ultimately al...               0
# 40  Developer added a new routine that was not ful...               0
# 41  Key resource tied to a previous project for tw...               0
# 42           Had only 1/3 of the units needed on time               0
# 43  New application works, but data collected is n...               0
# 44  Project team members reassigned.  Not replaced...               0
# 45   Freelancer  hired was a  nutjob, and lacked t...               0
# 46  Upgrade to software required.  Planning and tr...               0
# 47  Six weeks in, a redesign to the most fundament...               0
# 48  Contributor couldn't work due to injury and ba...               0
# 49  Needed system delivered to wrong building; los...               0
#
#       Region      Project  Year      Month     Cost
# 0   Americas  IT/Solution  2010  September  2535416
# 1   Americas   Prod. Dev.  2010   February  2533232
# 2   Americas  IT/Solution  2010        May  2526342
# 3   Americas  IT/Solution  2002    January  2437292
# 4   Americas  IT/Solution  2006      March  2383512
# 5   Americas  IT/Solution  2019   December  2371375
# 6   Americas  IT/Solution  2014   November  2366784
# 7   Americas   Prod. Dev.  2010   November  2360300
# 8   Americas   Prod. Dev.  2017      March  2350920
# 9   Americas   Prod. Dev.  2015     August  2324688
# 10  Americas  IT/Solution  2010   February  2316300
# 11  Americas   Prod. Dev.  2015  September  2292350
# 12  Americas  IT/Solution  2016    January  2286108
# 13  Americas  IT/Solution  2015  September  2285325
# 14  Americas   Prod. Dev.  2008      April  2276500
# 15  Americas  IT/Solution  2008    January  2276126
# 16  Americas  IT/Solution  2015        May  2265925
# 17  Americas  IT/Solution  2010       July  2259957
# 18  Americas   Prod. Dev.  2015        May  2257500
# 19  Americas  IT/Solution  2002       June  2227875
# 20  Americas  IT/Solution  2010   February  2227527
# 21  Americas  IT/Solution  2014    January  2226432
# 22  Americas  IT/Solution  2003   February  2200725
# 23  Americas   Prod. Dev.  2015   November  2180992
# 24  Americas  IT/Solution  2015       June  2164214
# 25  Americas   Prod. Dev.  2015   November  2161575
# 26  Americas  IT/Solution  2010      March  2149800
# 27  Americas   Prod. Dev.  2010       July  2127450
# 28  Americas   Prod. Dev.  2015     August  2095208
# 29  Americas  IT/Solution  2011     August  2092333
# 30  Americas   Prod. Dev.  2015      April  2088676
# 31  Americas  IT/Solution  2010       July  2085275
# 32  Americas  IT/Solution  2003       July  2075050
# 33  Americas   Prod. Dev.  2010      April  2018520
# 34  Americas  IT/Solution  2003      March  2002488
# 35  Americas  IT/Solution  2015    October  1999221
# 36  Americas   Prod. Dev.  2002       July  1994169
# 37  Americas  IT/Solution  2015  September  1987920
# 38  Americas  IT/Solution  2010  September  1985688
# 39  Americas   Prod. Dev.  2015       July  1975996
# 40  Americas   Prod. Dev.  2008    October  1974674
# 41  Americas  IT/Solution  2015      March  1973680
# 42  Americas  IT/Solution  2015    October  1972475
# 43  Americas  IT/Solution  2005   December  1961206
# 44  Americas  IT/Solution  2010        May  1955856
# 45  Americas  IT/Solution  2015  September  1952040
# 46  Americas   Prod. Dev.  2016      April  1933950
# 47  Americas  IT/Solution  2011       July  1928602
# 48  Americas  IT/Solution  2010        May  1926181
# 49  Americas  IT/Solution  2015  September  1923300

# %% [markdown]
# __What if we want to see the data for projects in the Americas that had a category of money? Let's also sort the data so we can see the projects with the highest cost failures first. See below for the code to do so, you can change the category that you would like by copying and pasting the category you want from above into the code below.__

# %% [markdown]
# For example, if I want to look at the project in the Americas where the category is People then I could copy and paste the code below: <br>
# category_filter = category_filter.sort_values(['Cost'], ascending = False) <br>
# dataset.loc[(dataset['Category'] == 'People') & (dataset['Region'] == 'Americas')] <br>
# category_filter = category_filter.reset_index(drop = True) <br>
# category_filter.head(50)

# %%
category_filter = dataset.loc[(dataset['Category'] == 'Money') & (dataset['Region'] == 'Americas')]
category_filter = category_filter.sort_values(['Cost'], ascending = False)
category_filter = category_filter.reset_index(drop = True) 
category_filter.head(50) #Let's look at the first 50 projects where the region is the Americas and the category is Money
# Out:
#     Project Number Parameter Category     Sub cat  Impact  TRL  \
# 0             4549  Resource    Money  Limitation      26    4
# 1             4133  Resource    Money  Limitation      24    6
# 2             4082  Resource    Money  Limitation      24    1
# 3             4434  Resource    Money  Limitation      26    6
# 4             4546  Resource    Money  Limitation      22    5
# 5             4435  Resource    Money  Limitation      19    6
# 6             1077  Resource    Money  Limitation      21    6
# 7             1132  Resource    Money  Limitation      22    3
# 8             4072  Resource    Money  Limitation      26    9
# 9             1480  Resource    Money  Limitation      21    6
# 10            1138  Resource    Money  Limitation      21    5
# 11            4369  Resource    Money  Limitation      24    5
# 12            4473  Resource    Money  Limitation      16    8
# 13            1100  Resource    Money  Limitation      20    6
# 14            1709  Resource    Money  Limitation      17    6
# 15            4292  Resource    Money  Limitation      16    7
# 16            2049  Resource    Money  Limitation      20    4
# 17            4553  Resource    Money  Limitation      23    6
# 18             531  Resource    Money  Limitation      15    6
# 19            4387  Resource    Money  Limitation      14    8
# 20            4300  Resource    Money  Limitation      15    2
# 21             937  Resource    Money  Limitation      15    5
# 22            1078  Resource    Money  Limitation      22    4
# 23            4134  Resource    Money  Limitation      17    7
# 24            1521  Resource    Money  Limitation      15    4
# 25            1963  Resource    Money  Limitation      22    5
# 26            2169  Resource    Money  Limitation      22    4
# 27            3293  Resource    Money  Limitation      15    4
# 28            1328  Resource    Money  Limitation      20    6
# 29             813  Resource    Money  Limitation      18    6
# 30            4445  Resource    Money  Limitation      17    2
# 31            2014  Resource    Money  Limitation      13    6
# 32            1400  Resource    Money  Limitation      16    3
# 33              76  Resource    Money  Limitation      15    6
# 34            2769  Resource    Money  Limitation      20    4
# 35            4361  Resource    Money  Limitation      15    2
# 36            2405  Resource    Money  Limitation      16    5
# 37            2048  Resource    Money  Limitation      22    7
# 38            1329  Resource    Money  Limitation      11    7
# 39             356  Resource    Money  Limitation      13    5
# 40             355  Resource    Money  Limitation      13    5
# 41            4004  Resource    Money  Limitation      10    8
# 42            1876  Resource    Money  Limitation      15    6
# 43             102  Resource    Money  Limitation      11    6
# 44              73  Resource    Money  Limitation      10    5
# 45            1453  Resource    Money  Limitation      12    4
# 46               0  Resource    Money  Limitation      18    5
# 47            2854  Resource    Money  Limitation      20    4
# 48             719  Resource    Money  Limitation      11    4
# 49            1405  Resource    Money  Limitation      15    4
#
#                                           Description  Region Numeric  \
# 0   "Minor" changes added  and accepted late in pr...               0
# 1          Shipping documents not filled in correctly               0
# 2   Components that could have been purchased were...               0
# 3   Key analyst is scheduled to work on another pr...               0
# 4   Project schedule was revised user interface re...               0
# 5   Architect who knew how to integrate all compon...               0
# 6                      Sponsor fails to provide money               0
# 7   IT department was underfunded and had insuffie...               0
# 8   Delay in getting material when a fermentation ...               0
# 9   Internal resources were not available on a ful...               0
# 10  Staffing was not sufficient to complete all as...               0
# 11  Online badge printing requirement completely m...               0
# 12  The key person responsible for major marketing...               0
# 13  Development team had insufficient resources as...               0
# 14      Chronically understaffed business environment               0
# 15  New equipment critical to the success of the p...               0
# 16                 Contractor setup delayed by a week               0
# 17                 Corporate merger delayed project                 0
# 18                Lack of funds for travel at launch                0
# 19  fittings and assemblies were not up to project...               0
# 20  Errors in input data had to be fixed and repor...               0
# 21  Without funding, all work ceased, contracts we...               0
# 22  Project needs $150K per month in supplies but ...               0
# 23  Dependency on other project not discovered unt...               0
# 24  Due to a layoff no writer was immediately avai...               0
# 25  Did not have sufficient  resources  and the co...               0
# 26             Lack of money for sufficient equipment               0
# 27  Project has funding, but limited staff delays ...               0
# 28     Insufficient resources assigned to the project               0
# 29  lack of staff availability due to company down...               0
# 30  Patch to software required for project work; e...               0
# 31  Major infrastructure project cut back; delayed...               0
# 32  The travel budget for the project was cut and ...               0
# 33                Project budget was dramatically cut               0
# 34          Delays due to bidding issues and protests               0
# 35  Details of requirements were submitted incorre...               0
# 36    Unexpectedly high demand requires outlisde help               0
# 37  Did not have sufficient resources and the cont...               0
# 38  Project Budget was restricted to the bare mini...               0
# 39  Development team had insufficient resources as...               0
# 40  Part of the project team ran of money three mo...               0
# 41  Contract had no penalties for missing deadline...               0
# 42                             Layoffs in mid-project               0
# 43   Project had limited funding and limited staffing               0
# 44  Failed to allocate enough resources and missed...               0
# 45             Lack of money for sufficient equipment               0
# 46  Did not have sufficient resources and the cont...               0
# 47    Unexpectedly high demand requires outlisde help               0
# 48                 Client slashed the original budget               0
# 49  Key consultant was let go at a critical time f...               0
#
#       Region      Project  Year      Month     Cost
# 0   Americas  IT/Solution  2002    January  2437292
# 1   Americas  IT/Solution  2006      March  2383512
# 2   Americas  IT/Solution  2017   December  1864824
# 3   Americas   Prod. Dev.  2015   November  1809678
# 4   Americas   Prod. Dev.  2010       July  1724844
# 5   Americas   Prod. Dev.  2010   February  1678745
# 6   Americas   Prod. Dev.  2007   November  1646505
# 7   Americas  IT/Solution  2019    January  1594516
# 8   Americas  IT/Solution  2014   February  1552278
# 9   Americas  IT/Solution  2007   December  1486023
# 10  Americas   Prod. Dev.  2019       July  1464645
# 11  Americas   Prod. Dev.  2001       June  1388904
# 12  Americas  IT/Solution  2015   December  1346976
# 13  Americas   Prod. Dev.  2017     August  1342380
# 14  Americas   Prod. Dev.  2016  September  1339753
# 15  Americas  IT/Solution  2010   December  1262176
# 16  Americas   Prod. Dev.  2019     August  1229220
# 17  Americas  IT/Solution  2006   February  1213710
# 18  Americas   Prod. Dev.  2014  September  1160100
# 19  Americas   Prod. Dev.  2008       July  1135526
# 20  Americas  IT/Solution  2007     August  1133325
# 21  Americas   Prod. Dev.  2001      March  1124565
# 22  Americas   Prod. Dev.  2007     August  1105742
# 23  Americas  IT/Solution  2013     August  1035181
# 24  Americas   Prod. Dev.  2009    January  1028115
# 25  Americas  IT/Solution  2019    January  1005026
# 26  Americas   Prod. Dev.  2019   November   981112
# 27  Americas  IT/Solution  2005      April   957585
# 28  Americas   Prod. Dev.  2007  September   930900
# 29  Americas  IT/Solution  2007   February   917766
# 30  Americas  IT/Solution  2002        May   885836
# 31  Americas  IT/Solution  2007       July   883350
# 32  Americas   Prod. Dev.  2003      March   849680
# 33  Americas  IT/Solution  2009        May   832665
# 34  Americas  IT/Solution  2010     August   822300
# 35  Americas   Prod. Dev.  2002       June   820110
# 36  Americas  IT/Solution  2013   December   809664
# 37  Americas  IT/Solution  2019      April   804584
# 38  Americas   Prod. Dev.  2009       June   785147
# 39  Americas   Prod. Dev.  2005  September   779298
# 40  Americas   Prod. Dev.  2009       July   777777
# 41  Americas  IT/Solution  2005     August   759950
# 42  Americas  IT/Solution  2013      March   758550
# 43  Americas  IT/Solution  2012      April   717541
# 44  Americas  IT/Solution  2002        May   708760
# 45  Americas   Prod. Dev.  2007     August   701112
# 46  Americas  IT/Solution  2010    October   700560
# 47  Americas  IT/Solution  2005       July   692300
# 48  Americas  IT/Solution  2014   December   673464
# 49  Americas  IT/Solution  2014   February   664230

# %% [markdown]
# __How can we visualize this filtered data to understand how TRL level effects the Impact value in projects in the Americas, in the Money Category?__

# %%
g = category_filter.groupby('TRL', as_index = False)['Impact'].mean()
g['Impact'] = g['Impact'].round(2)
g
# Out:
#    TRL  Impact
# 0    1   14.75
# 1    2   13.50
# 2    3   12.45
# 3    4   14.17
# 4    5   14.71
# 5    6   15.54
# 6    7   11.78
# 7    8   10.75
# 8    9   22.00

# %%
plt.figure(figsize = (3,10))
h = plt.bar(g['TRL'],g['Impact'])
plt.xlabel('TRL')
plt.ylabel('Impact (in Weeks)')
plt.title('Average Impact by TRL for Projects in the Americas with a Failure in the Money Category')
h
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# __Now that we can we graph this data easily and analyze the data for our understanding? Let's start with understanding how the average cost per failure varies by region.__

# %%
y = dataset.groupby('Region', as_index = False)['Cost'].mean()
y['Cost'] = y['Cost'].round(2)
y
# Out:
#      Region       Cost
# 0    Africa  744616.68
# 1  Americas  752808.41
# 2      Asia  724886.88
# 3    Eur/ME  778307.72

# %%
plt.figure(figsize = (3,10))
a = plt.bar(y['Region'],y['Cost'])
plt.xlabel('Region')
plt.ylabel('Average Cost (in USD)')
plt.title('Average Cost (in USD) per Region')
a
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# __What is the Average Cost Per Year for all the Projects?__

# %%
z = dataset.groupby('Year', as_index = False)['Cost'].mean()
z['Cost'] = z['Cost'].round(2)
z.sort_values(by = ['Year'])
z
# Out:
#     Year       Cost
# 0   2001  766136.24
# 1   2002  775338.76
# 2   2003  751868.87
# 3   2004  760491.31
# 4   2005  714075.49
# 5   2006  715143.45
# 6   2007  711551.25
# 7   2008  729581.87
# 8   2009  782631.19
# 9   2010  801956.27
# 10  2011  759503.60
# 11  2012  705645.49
# 12  2013  701452.11
# 13  2014  733437.70
# 14  2015  875305.61
# 15  2016  729610.30
# 16  2017  770409.96
# 17  2018  764912.75
# 18  2019  699717.54

# %%
b = plt.plot(z['Year'],z['Cost'])
plt.xlabel('Year')
plt.ylabel('Average Cost (in USD)')
plt.title('Average Cost (in USD) over Time for Project Failures in all Regions')
plt.xticks(np.arange(2001, 2020, 2)) 
b

# %%
y = region_filter.groupby('Year', as_index = False)['Cost'].mean()
y['Cost'] = y['Cost'].round(2)
y = y.sort_values(by = ['Year'])
y
# Out:
#     Year       Cost
# 0   2001  753027.31
# 1   2002  759695.25
# 2   2003  730311.18
# 3   2004  734516.43
# 4   2005  694079.68
# 5   2006  704339.55
# 6   2007  697654.34
# 7   2008  724117.90
# 8   2009  800630.01
# 9   2010  841943.56
# 10  2011  768046.24
# 11  2012  743514.16
# 12  2013  646923.40
# 13  2014  752774.03
# 14  2015  901210.34
# 15  2016  682162.81
# 16  2017  802036.48
# 17  2018  741020.30
# 18  2019  666180.41

# %% [markdown]
# __Now let's look at the Average Cost Per Year for Projects in the Americas.__

# %%
a = plt.plot(y['Year'],y['Cost'])
plt.xlabel('Year')
plt.ylabel('Average Cost (in USD)')
plt.title('Average Cost (in USD) over Time for Project Failures in the Americas Region')
plt.xticks(np.arange(2001, 2020, 2)) 
a

# %% [markdown]
# __Let's take this one step further - what if we look at the average cost for projects in all the regions but the Americas? First we'll filter the data to only include projects in the Asia, Eur/ME, and Africa regions. Let's also sort the data so we can see the projects with the highest cost failures first.__

# %%
region_filter_no_americas = dataset.loc[dataset['Region'] != 'Americas']
region_filter_no_americas = region_filter_no_americas.sort_values(['Cost'], ascending = False)
region_filter_no_americas = region_filter_no_americas.reset_index(drop = True) 
region_filter_no_americas.head(50) #Let's look at the first 50 projects that are not in the Americas region
# Out:
#     Project Number Parameter     Category              Sub cat  Impact  TRL  \
# 0             3842  Resource       People           Late start      26    3
# 1             4940     Scope       Change                  Gap      26    8
# 2             3705  Resource  Outsourcing        Delayed start      26    2
# 3             4991  Resource       People                 Loss      26    2
# 4             4788  Resource       People                 Loss      25    2
# 5             4552  Resource        Money           Limitation      26    7
# 6             3394  Schedule   Dependency       Infrastructure      26    6
# 7             4843  Resource  Outsourcing           Late start      25    4
# 8             4797     Scope       Change                Creep      24    7
# 9             3523     Scope       Change                  Gap      24    8
# 10            4641  Resource       People            Temp loss      24    5
# 11            4869  Resource       People            Temp loss      25    5
# 12            4756     Scope       Change                  Gap      25    2
# 13            4568  Resource       People              Queuing      25    5
# 14            4675  Schedule        Delay          Information      25    4
# 15            3617     Scope       Change                Creep      25    1
# 16            3897     Scope       Change                Creep      26    9
# 17            4864  Resource       People              Queuing      23    1
# 18            4083  Schedule    Estimates             Learning      22    5
# 19            4883  Schedule        Delay                Parts      24    4
# 20            4160  Schedule        Delay                Parts      24    7
# 21            4000  Resource       People                 Loss      26    9
# 22            3518  Schedule        Delay             Decision      24    2
# 23            4437  Resource        Money           Limitation      26    5
# 24            3726  Resource       People                 Loss      24    9
# 25            3831  Schedule        Delay             Hardware      22    4
# 26            4835  Resource  Outsourcing  Late or poor output      24    7
# 27            4682  Schedule        Delay                Parts      26    3
# 28            3345  Resource       People            Temp loss      24    8
# 29            4318  Resource       People            Temp loss      22    2
# 30            3557  Resource       People              Queuing      24    3
# 31            3857  Resource       People                 Loss      25    7
# 32            3556  Resource       People              Queuing      25    1
# 33            3898  Resource  Outsourcing  Late or poor output      21    5
# 34            3878  Resource  Outsourcing  Late or poor output      22    8
# 35            3235     Scope       Defect             Hardware      21    9
# 36            3577  Schedule        Delay          Information      22    3
# 37            4816     Scope       Change                Creep      20    3
# 38            4517     Scope       Change                Creep      20    9
# 39            4449  Resource       People              Queuing      22    3
# 40            4637  Resource       People              Queuing      21    9
# 41            4815     Scope       Change                Creep      20    5
# 42            3800  Schedule        Delay                Parts      24    4
# 43            3191  Resource       People            Temp loss      21    9
# 44            4477  Resource  Outsourcing  Late or poor output      22    7
# 45            4669  Schedule        Delay             Hardware      23    9
# 46            4326  Resource       People              Queuing      25    6
# 47            3574  Schedule        Delay             Hardware      26    7
# 48            4405     Scope       Change                Creep      24    5
# 49            3673     Scope       Defect             Hardware      22    4
#
#                                           Description  Region Numeric  Region  \
# 0   Change Management Lead took unexpected medical...               1    Asia
# 1   Chip failed and had to be refabricated with ch...               2  Eur/ME
# 2   Project had to wait until all data collection ...               2  Eur/ME
# 3   To expand business, unrealistic commitments we...               3  Africa
# 4   Contract lab failed to inform us that they had...               3  Africa
# 5   Server technology chage was necessitated to su...               2  Eur/ME
# 6        Need to upgrade detected only at project end               2  Eur/ME
# 7   Internal supplier problem; needed components d...               3  Africa
# 8                Late test results came back negative               3  Africa
# 9   Several employees had to take a leave of absen...               1    Asia
# 10  Delay in hiring more engineers due to cost cut...               3  Africa
# 11  Some of the cross functional teams were not in...               3  Africa
# 12  Insufficient length of anchor bolts protruding...               2  Eur/ME
# 13  Insufficient initial project scope was defined...               2  Eur/ME
# 14                Key parts would be delivered late                 2  Eur/ME
# 15  New database wouldn’t work with the proposed p...               2  Eur/ME
# 16  Multiple projects depend on lone expert scientist               1    Asia
# 17  Lack of understanding by the manager of the sy...               2  Eur/ME
# 18  Project delayed due to recent/last minute chan...               1    Asia
# 19  Apartments were sold before construction begin...               2  Eur/ME
# 20  Cable required had been left off the implement...               2  Eur/ME
# 21  Client requested "15 minute" change accepted a...               1    Asia
# 22                              Poor Fit/Gap analysis               1    Asia
# 23  None of the developers had experience with the...               2  Eur/ME
# 24  Project start delayed; staffing and buy-in lat...               1    Asia
# 25  After more than 2/3 of the original budget had...               2  Eur/ME
# 26  Parallel tasks require resources beyond what i...               2  Eur/ME
# 27     Supplier was unable to make a sample correctly               2  Eur/ME
# 28    Scope expanded during the course of the project               1    Asia
# 29  Move out of old location required, but new spa...               2  Eur/ME
# 30  Inadequate procedures for acceptance, quality,...               1    Asia
# 31  Team was staffed by 3 successive new hires in ...               2  Eur/ME
# 32  A pool of unqualified, poorly performing, marg...               1    Asia
# 33        Errors found  in data and critrical reports               1    Asia
# 34             Late stakeholders redefine requiremnts               2  Eur/ME
# 35  Conversion from legacy system to SAP has multi...               2  Eur/ME
# 36  Project team was not aware that the new releas...               2  Eur/ME
# 37                                Inadequate staffing               2  Eur/ME
# 38                Needed wiring not available on time               2  Eur/ME
# 39  Work at customer site had to be done by union ...               2  Eur/ME
# 40  Contract lab failed to inform us that they had...               2  Eur/ME
# 41                 Client slashed the original budget               3  Africa
# 42  Did not have the correct people validate requi...               1    Asia
# 43  Redesign required late in printer project to m...               2  Eur/ME
# 44  All students did not complete training as sche...               2  Eur/ME
# 45  Decisions are being delayed without apparent r...               3  Africa
# 46  Approvals held up at project completion to wai...               2  Eur/ME
# 47  In creating a new system, there was too little...               1    Asia
# 48   Delay in patient recruitment for clinical trials               2  Eur/ME
# 49  No understanding of the scope and not enough s...               1    Asia
#
#         Project  Year      Month     Cost
# 0   IT/Solution  2003   November  2562560
# 1   IT/Solution  2018    January  2548442
# 2    Prod. Dev.  2001    October  2543034
# 3    Prod. Dev.  2004        May  2504268
# 4    Prod. Dev.  2002   December  2469325
# 5    Prod. Dev.  2015   December  2425748
# 6    Prod. Dev.  2003      March  2357602
# 7    Prod. Dev.  2013       June  2326750
# 8   IT/Solution  2011    January  2309472
# 9    Prod. Dev.  2011     August  2301120
# 10  IT/Solution  2010       June  2286048
# 11  IT/Solution  2010    October  2242050
# 12  IT/Solution  2018     August  2237275
# 13  IT/Solution  2005      April  2218325
# 14  IT/Solution  2018  September  2206475
# 15  IT/Solution  2015        May  2204675
# 16   Prod. Dev.  2006     August  2194530
# 17   Prod. Dev.  2007      April  2157676
# 18   Prod. Dev.  2014      March  2150148
# 19  IT/Solution  2007   December  2124000
# 20  IT/Solution  2006      April  2106312
# 21   Prod. Dev.  2003   November  2098902
# 22   Prod. Dev.  2006   November  2094336
# 23   Prod. Dev.  2009       July  2093078
# 24  IT/Solution  2011       June  2090328
# 25   Prod. Dev.  2003      March  2085204
# 26  IT/Solution  2001       July  2082432
# 27  IT/Solution  2004    January  2081560
# 28  IT/Solution  2017   December  2055624
# 29  IT/Solution  2017   November  2052248
# 30   Prod. Dev.  2015        May  2052144
# 31  IT/Solution  2010      March  2050425
# 32   Prod. Dev.  2013  September  2041850
# 33  IT/Solution  2011      March  2040171
# 34  IT/Solution  2017      April  2035968
# 35  IT/Solution  2017      April  2033829
# 36  IT/Solution  2016    January  2023054
# 37   Prod. Dev.  2018      March  1997540
# 38   Prod. Dev.  2002   February  1992660
# 39   Prod. Dev.  2002       June  1991176
# 40  IT/Solution  2015      April  1977528
# 41   Prod. Dev.  2018   February  1974940
# 42  IT/Solution  2004   February  1971720
# 43   Prod. Dev.  2003    October  1971123
# 44  IT/Solution  2019    October  1968626
# 45   Prod. Dev.  2013       June  1964062
# 46  IT/Solution  2003       June  1960725
# 47   Prod. Dev.  2002     August  1952574
# 48  IT/Solution  2008    January  1948032
# 49   Prod. Dev.  2001      March  1934790

# %%
c = region_filter_no_americas.groupby('Year', as_index = False)['Cost'].mean()
c['Cost'] = c['Cost'].round(2)
c = c.sort_values(by = ['Year'])
c
# Out:
#     Year       Cost
# 0   2001  779125.99
# 1   2002  795394.55
# 2   2003  774372.07
# 3   2004  784885.11
# 4   2005  733375.79
# 5   2006  727068.51
# 6   2007  744882.14
# 7   2008  734674.51
# 8   2009  757989.94
# 9   2010  730288.23
# 10  2011  749011.00
# 11  2012  669423.28
# 12  2013  756446.87
# 13  2014  713904.06
# 14  2015  806226.34
# 15  2016  789172.05
# 16  2017  742397.90
# 17  2018  785768.02
# 18  2019  792031.09

# %%
l = plt.plot(c['Year'],c['Cost'])
plt.xlabel('Year')
plt.ylabel('Average Cost (in USD)')
plt.title('Average Cost (in USD) over Time for Project Failures not in the Americas Region')
plt.xticks(np.arange(2001, 2020, 2)) 
l

# %% [markdown]
# __Now that we've looked at the cost breakdown over time per region - let's look at the difference in the average Impact (in weeks) per region.__

# %%
d = dataset.groupby('Region', as_index = False)['Impact'].mean()
d['Impact'] = d['Impact'].round(2)
d
# Out:
#      Region  Impact
# 0    Africa   13.53
# 1  Americas   13.51
# 2      Asia   13.29
# 3    Eur/ME   13.41

# %% [markdown]
# __Let's also take a look at how TRL values affect Impact.__

# %%
e = dataset.groupby('TRL', as_index = False)['Impact'].mean()
e['Impact'] = e['Impact'].round(2)
e
# Out:
#    TRL  Impact
# 0    1   13.70
# 1    2   13.13
# 2    3   13.45
# 3    4   13.37
# 4    5   13.76
# 5    6   13.83
# 6    7   13.43
# 7    8   12.82
# 8    9   12.29

# %%
plt.figure(figsize = (3,10))
f = plt.bar(e['TRL'],e['Impact'])
plt.xlabel('TRL')
plt.ylabel('Average Impact (in Weeks)')
plt.title('Average Impact (in Weeks) per TRL')
plt.yticks(np.arange(0, 13, 3)) 
f
# Out:
# <BarContainer object of 9 artists>
